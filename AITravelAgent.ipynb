# %% [markdown]
# <a href="https://colab.research.google.com/github/auromaa-2004/TravelAgent/blob/main/AITravelAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install groq

# %%
# !pip install python-dotenv

# %%
import os
from dotenv import dotenv_values,load_dotenv,find_dotenv
_=load_dotenv(find_dotenv())
# Load and print only the keys from .env
env_vars = dotenv_values(".env")
# print("Keys in .env file:", list(env_vars.keys()))

print('groq_api_key' in os.environ)
api_key=os.environ['groq_api_key']
# print(api_key)
# Out:
# True

# %% [markdown]
# Defining tool for the function

# %%
pip install google-search-results

# %%
import json
from functools import wraps
import requests

def tool(fn):
    """
    Custom decorator to turn a function into a tool.
    This stores metadata about the function for an AI agent to use.
    """
    @wraps(fn)
    def wrapper(*args, **kwargs):
        return fn(*args, **kwargs)  # Call the original function

    # Add metadata so the AI agent can understand the tool
    wrapper.name = fn.__name__  # Function name
    wrapper.description = fn.__doc__  # Function docstring (description)

    return wrapper  # Return the modified function

# %%
import os
from dotenv import dotenv_values,load_dotenv,find_dotenv
_=load_dotenv(find_dotenv())
# Load and print only the keys from .env
env_vars = dotenv_values(".env")
print("Keys in .env file:", list(env_vars.keys()))

print('google_flights_apikey_2' in os.environ)
flight_api=os.environ['google_flights_apikey_2']
print(flight_api)
# Out:
# Keys in .env file: ['MyEnvVar', 'groq_api_key', 'google_flights_apikey_2', 'hotel_api', 'hotel_api_secret', 'weather_api_key']
# True
# 75d9acc884b67fb512c597f6d18338743d631b118a4aa686ee86c16292252365

# %% [markdown]
# ##  FLIGHT BOOKING

# %%
from serpapi import GoogleSearch
from datetime import datetime
@tool
def search_flights(origin, destination, departure_date,return_date,flight_api_key):
  """
  Search for available flights based on input parameters.
  Retrieves top flight recommendations based on user's travel style as JSON.
  """
  indian_airports={
  "agartala": "IXA",
  "agatti": "AGX",
  "agra": "AGR",
  "ahmedabad": "AMD",
  "aizawl": "AJL",
  "akola": "AKD",
  "allahabad": "IXD",
  "along": "IXV",
  "amritsar": "ATQ",
  "aurangabad": "IXU",
  "bagdogra": "IXB",
  "balurghat": "RGH",
  "bangalore": "BLR",
  "bareilly": "BEK",
  "belgaum": "IXG",
  "bellary": "BEP",
  "bhatinda": "BUP",
  "bhavnagar": "BHU",
  "bhopal": "BHO",
  "bhubaneswar": "BBI",
  "bhuj": "BHJ",
  "bikaner": "BKB",
  "bilaspur": "PAB",
  "car nicobar": "CBD",
  "chandigarh": "IXC",
  "chennai": "MAA",
  "cochin": "COK",
  "coimbatore": "CJB",
  "cooch behar": "COH",
  "cuddapah": "CDP",
  "daman": "NMB",
  "daporijo": "DEP",
  "darjeeling": "DAI",
  "dehradun": "DED",
  "dhanbad": "DBD",
  "dibrugarh": "DIB",
  "dimapur": "DMU",
  "diu": "DIU",
  "durgapur": "RDP",
  "guwahati": "GAU",
  "gaya": "GAY",
  "goa": "GOI",
  "gorakhpur": "GOP",
  "guna": "GUX",
  "gwalior": "GWL",
  "hissar": "HSS",
  "hubli": "HBX",
  "hyderabad": "HYD",
  "imphal": "IMF",
  "indore": "IDR",
  "jabalpur": "JLR",
  "jagdalpur": "JGB",
  "jaipur": "JAI",
  "jaisalmer": "JSA",
  "jamnagar": "JGA",
  "jamshedpur": "IXW",
  "jeypore": "PYB",
  "jodhpur": "JDH",
  "jammu": "IXJ",
  "jorhat": "JRH",
  "kailashahar": "IXH",
  "kamalpur": "IXQ",
  "kandla": "IXY",
  "kangra": "DHM",
  "kanpur": "KNU",
  "keshod": "IXK",
  "khajuraho": "HJR",
  "khowai": "IXN",
  "kolhapur": "KLH",
  "kolkata": "CCU",
  "kota": "KTU",
  "kozhikode": "CCJ",
  "kullu manali": "KUU",
  "latur": "LTU",
  "leh": "IXL",
  "lilabari": "IXI",
  "lucknow": "LKO",
  "ludhiana": "LUH",
  "madurai": "IXM",
  "malda": "LDA",
  "mangalore": "IXE",
  "mohanbari": "MOH",
  "mumbai": "BOM",
  "muzaffarnagar": "MZA",
  "muzaffarpur": "MZU",
  "mysore": "MYQ",
  "nagpur": "NAG",
  "nanded": "NDC",
  "new delhi": "DEL",
  "neyveli": "NVY",
  "osmanabad": "OMN",
  "pantnagar": "PGH",
  "pasighat": "IXT",
  "pathankot": "IXP",
  "patna": "PAT",
  "pondicherry": "PNY",
  "porbandar": "PBD",
  "port blair": "IXZ",
  "pune": "PNQ",
  "puttaparthi": "PUT",
  "raipur": "RPR",
  "rajahmundry": "RJA",
  "rajkot": "RAJ",
  "rajouri": "RJI",
  "ramagundam": "RMD",
  "ranchi": "IXR",
  "ratnagiri": "RTC",
  "rewa": "REW",
  "rourkela": "RRK",
  "rupsi india": "RUP",
  "salem": "SXV",
  "satna": "TNI",
  "shillong": "SHL",
  "shimla": "SLV",
  "silchar": "IXS",
  "solapur": "SSE",
  "srinagar": "SXR",
  "surat": "STV",
  "tezpur": "TEZ",
  "tezu": "TEI",
  "thanjavur": "TJV",
  "thiruvananthapuram": "TRV",
  "thoothukudi": "TCR",
  "tiruchirapally": "TRZ",
  "tirupati": "TIR",
  "vadodara": "BDQ",
  "varanasi": "VNS",
  "vijayanagar": "VDY",
  "vijayawada": "VGA",
  "vishakhapatnam": "VTZ",
  "warangal": "WGC",
  "zero": "ZER"
  }
  origin=indian_airports[origin.lower()]
  # print(origin)
  destination=indian_airports[destination.lower()]
  # print(destination)
  params = {
    "engine": "google_flights",
    "departure_id": origin,
    "arrival_id": destination,
    "outbound_date": departure_date,
    "return_date": return_date,
    "currency": "USD",
    "hl": "en",
    "api_key": flight_api,
  }

  search = GoogleSearch(params)
  results = search.get_dict()
  if "error" in results:
    return "No flights available"
  filtered_results = []
  if "best_flights" in results:
    for flight_data in results["best_flights"][:5]:
        flight = flight_data["flights"][0]  # Extract the first flight from the list

        filtered_results.append({
            "departure airport": flight.get("departure_airport", {}).get("name", "N/A"),
            "arrival airport": flight.get("arrival_airport", {}).get("name", "N/A"),
            "airplane": flight.get("airplane", "N/A"),
            "airline": flight.get("airline", "N/A"),
            "travel_class": flight.get("travel_class", "N/A"),
            "total_duration": flight_data.get("total_duration", "N/A"),  # Use `flight_data`, as total duration is outside "flights"
            "price": flight_data.get("price", "N/A"),  # Price is also outside "flights"
        })

    return json.dumps(filtered_results, indent=4)
  # print("DEBUG: API Response =", results)

  formatted_results = json.dumps(results, indent=4)
  return formatted_results

origin = "bhubaneswar"
destination = "Bangalore"
departure_date = "2025-04-10"
return_date="2025-04-15"
travel_style = "Luxury"

flight_results = search_flights(origin, destination, departure_date,return_date,flight_api)
print(flight_results)
# Out:
# [
#     {
#         "departure airport": "Biju Patnaik International Airport",
#         "arrival airport": "Kempegowda International Airport Bengaluru",
#         "airplane": "Airbus A320neo",
#         "airline": "IndiGo",
#         "travel_class": "Economy",
#         "total_duration": 135,
#         "price": 124
#     },
#     {
#         "departure airport": "Biju Patnaik International Airport",
#         "arrival airport": "Kempegowda International Airport Bengaluru",
#         "airplane": "Airbus A320neo",
#         "airline": "IndiGo",
#         "travel_class": "Economy",
#         "total_duration": 130,
#         "price": 124
#     },
#     {
#         "departure airport": "Biju Patnaik International Airport",
#         "arrival airport": "Kempegowda International Airport Bengaluru",
#         "airplane": "Airbus A320neo",
#         "airline": "IndiGo",
#         "travel_class": "Economy",
#         "total_duration": 130,
#         "price": 124
#     },
#     {
# ...

# %% [markdown]
# # **HOTEL** **BOOKING**

# %%
pip install google-search-results

# %%
import os
from dotenv import dotenv_values,load_dotenv,find_dotenv
_=load_dotenv(find_dotenv())
# Load and print only the keys from .env
env_vars = dotenv_values(".env")
print("Keys in .env file:", list(env_vars.keys()))

print('google_flights_apikey_2' in os.environ)
flight_api=os.environ['google_flights_apikey_2']
print(flight_api)
# Out:
# Keys in .env file: ['MyEnvVar', 'groq_api_key', 'google_flights_apikey_2', 'hotel_api', 'hotel_api_secret', 'weather_api_key']
# True
# 75d9acc884b67fb512c597f6d18338743d631b118a4aa686ee86c16292252365

# %%
from serpapi import GoogleSearch
from datetime import datetime
@tool
def search_hotels(place,check_in_date, check_out_date,adults,flight_api_key):
  """
  Search for available hotels based on input parameters.
  Retrieves top hotel recommendations based on user's requiremnets as JSON.
  """

  params = {
  "engine": "google_hotels",
  "q": f"{place} Hotels",
  "check_in_date": check_in_date,
  "check_out_date": check_out_date,
  "adults": adults,
  "hl": "en",
  "api_key": flight_api_key
  }

  search = GoogleSearch(params)
  results = search.get_dict()
  # print("DEBUG: API Response =", results)
  filtered_results=[]
  if "properties" in results:
        for hotel in results["properties"][:20]:  # Limit to top 20 results
            filtered_results.append({
                "name": hotel.get("name", "N/A"),
                "ratings": hotel.get("ratings", [{"stars": "N/A"}])[0].get("stars", "N/A"),
                "reviews": hotel.get("reviews", "N/A"),
                "price": (
                    hotel.get("prices", [{}])[0].get("rate_per_night", {}).get("lowest", "N/A")
                    if "prices" in hotel else
                    hotel.get("rate_per_night", {}).get("lowest", "N/A")
                ),
                "location": hotel.get("gps_coordinates", "N/A"),
                "class": hotel.get("hotel_class", "N/A")
            })

  return json.dumps(filtered_results, indent=4)
  print(filtered_results)
  formatted_results = json.dumps(results, indent=4)
  return formatted_results

check_in_date="2025-04-10"
check_out_date = "2025-04-14"
adults="2"
place="Varanasi"
hotel_results = search_hotels(place,check_in_date, check_out_date,adults,flight_api)
print(hotel_results)
# Out:
# [
#     {
#         "name": "Pearl Courtyard",
#         "ratings": 5,
#         "reviews": 1906,
#         "price": "$73",
#         "location": {
#             "latitude": 25.3094437,
#             "longitude": 83.0044412
#         },
#         "class": "4-star hotel"
#     },
#     {
#         "name": "Narayana Haveli - Varanasi",
#         "ratings": 5,
#         "reviews": 168,
#         "price": "$21",
#         "location": {
#             "latitude": 25.302923699999997,
#             "longitude": 83.0066216
#         },
#         "class": "N/A"
#     },
#     {
#         "name": "Taj Ganges, Varanasi",
#         "ratings": 5,
#         "reviews": 8384,
#         "price": "N/A",
#         "location": {
#             "latitude": 25.336095699999998,
#             "longitude": 82.98636259999999
#         },
#         "class": "5-star hotel"
#     },
#     {
#         "name": "STAY BANARAS",
#         "ratings": 5,
#         "reviews": 1513,
#         "price": "$59",
# ...

# %% [markdown]
# ## **WEATHER**

# %%
import requests
import os
from dotenv import dotenv_values,load_dotenv,find_dotenv
_=load_dotenv(find_dotenv())
# Load and print only the keys from .env
env_vars = dotenv_values(".env")
print("Keys in .env file:", list(env_vars.keys()))

print('weather_api_key' in os.environ)
weather_api_key=os.environ['weather_api_key']
print(weather_api_key)
import requests
from datetime import datetime, timedelta

def get_future_weather(city, future_date):
    api_key =weather_api_key   # Replace with your API key
    url = f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"

    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()

        # Convert future_date to timestamp
        future_timestamp = datetime.strptime(future_date, "%Y-%m-%d").timestamp()

        closest_forecast = None
        min_time_diff = float('inf')

        # Find the closest forecast time to the requested date
        for forecast in data["list"]:
            forecast_timestamp = forecast["dt"]
            time_diff = abs(forecast_timestamp - future_timestamp)

            if time_diff < min_time_diff:
                min_time_diff = time_diff
                closest_forecast = forecast

        if closest_forecast:
            weather = {
                "Date": future_date,
                "City": data["city"]["name"],
                "Temperature": closest_forecast["main"]["temp"],
                "Weather": closest_forecast["weather"][0]["description"],
                "Humidity": closest_forecast["main"]["humidity"],
                "Wind Speed": closest_forecast["wind"]["speed"]
            }
            return weather
        else:
            return "No forecast available for this date."
    else:
        return f"Error: {response.status_code}, {response.text}"

city = input("Enter city name: ")
future_date = input("Enter future date (YYYY-MM-DD): ")
weather_info = get_future_weather(city, future_date)
print(weather_info)
# Out:
# Keys in .env file: ['MyEnvVar', 'groq_api_key', 'google_flights_apikey_2', 'hotel_api', 'hotel_api_secret', 'weather_api_key']
# True
# fb03f52f63d5e817dd97ae3a5b40468a
# Enter city name: rourkela
# Enter future date (YYYY-MM-DD): 2025-03-30
# {'Date': '2025-03-30', 'City': 'Rourkela', 'Temperature': 40.22, 'Weather': 'clear sky', 'Humidity': 7, 'Wind Speed': 2.69}

# %%
import os
from groq import Groq
# date=input(("Enter checkin date you want to visit (YYYY-MM-DD):"))
# check_in_date=date
# check_out_date=input(("Enter date you want to leave (YYYY-MM-DD):"))
# city=input("Enter city you want to visit:")
# adults=int(input("No. of adults:"))
# origin=input("From where do you want to board the flight:")
# travel_style=input("Budget friendly , Moderate , Luxury ,Family friendly?")
date="2025-04-01"
check_in_date=date
check_out_date="2025-04-05"
city="Bangalore"
adults=2
origin="bhubaneswar"
travel_style="Budget friendly"
interests="food"
description="I want to eat at Rameswaram Hotel."

client = Groq(api_key=api_key)
weather_data = get_future_weather(city,date)  # Your function to fetch weather data
hotels_data = search_hotels(city,check_in_date, check_out_date,adults,flight_api)  # Your function to fetch flight data
going_flights_data = search_flights(origin, city, check_in_date,check_out_date,flight_api)
# Your function to fetch hotel data
# print(weather_data,hotels_data,flights_data)
def ask_ai(prompt):
  message=[{
      "role":"system",
      "content": "You are a professional itinerary planner. Provide responses in pure JSON format with no additional explanations."
  },{
      "role":"user",
      "content":prompt,
  }]
  response=client.chat.completions.create(
    messages=message,
    model="llama-3.1-8b-instant"
  )
  return response.choices[0].message.content
prompt = (
    f"""
    Using weather responses from {weather_data}, hotel data from {hotels_data} and flight details from {going_flights_data},
    based on {check_in_date} and {check_out_date} and number of {adults},
    Generate a detailed travel itinerary for {city} in JSON format.
    In JSON format, make sure to send in the format:
    for hotel:
    "hotel": {{
      "name":
      "ratings":
      "reviews":
      "price":
      "location": {{
        "latitude":
        "longitude":
    }},
    "class":
    }}
    for flight:
    "flight":{{
      "airline":
      "source":
      "destination":
      "departure":
      "arrival":
      "price":
    }}
    for itenary:
    date of the day:
        "weather":{{
          "Temperature":
          "Weather":
          "Humidity":
          "Wind Speed":
        }}
        "itenary": {{
          "date":
          "timings":
          "activity":
          "location":
          "transportation":
          "estimated costs":
          }}
    If any field is unavailable, exclude it completely instead of returning null.
    Fetch weather data using {get_future_weather(city,date)} and decide the itenary for that day.
    Change to indoors if weather conditions are not suitable.
    Change itenary accordingly if user provides some {description}.
    Choose the best results from the hotel and flight detail as per the {travel_style} and {interests} of the user.
    If no data for flight is available, search for the nearest airports from where there can be flight connectivity from {origin}.
    Convert all dollar prices to INR.
    Give only the hotel details and flight details before generating the itenary.
    Please provide a detailed day-by-day itinerary including all:
        - Suggested atleast 4 activities from day to night for all days
        - Recommended restaurants for meals
        - Transportation details
        - Estimated costs in INR
        - Time allocations
      for each day and acitivity.
      Check whether that site is actually availabe to visit or not in that day.
      Provide weather details for each day before that day's itenary response.
    Give the output in format mentioned above strictly. Do not add fills beyond the given structure.
    Keep in mind to keep the response in specified JSON format only, as mentioned above.
    """)
response=ask_ai(prompt)
print(response)
# Out:
# {
#     "hotel": {
#       "name": "Fairfield by Marriott Bengaluru Rajajinagar",
#       "ratings": 5,
#       "reviews": 7783,
#       "price": 5819,
#       "location": {
#         "latitude": 12.9830936,
#         "longitude": 77.5593393
#       },
#       "class": "4-star hotel"
#     },
#     "flight":{
#       "airline": "IndiGo",
#       "source": "Biju Patnaik International Airport",
#       "destination": "Kempegowda International Airport Bengaluru",
#       "departure": "2025-04-01",
#       "arrival": "2025-04-01",
#       "price": 9026
#     }
# }
#
# {
#     "weather": {
#       "Temperature": 23.4,
#       "Weather": "partly cloudy",
#       "Humidity": 54,
#       "Wind Speed": 3.18
#     },
#     "itenary": [
#       {
#         "date": "2025-04-01",
#         "timings": "9:00 AM - 10:00 AM",
#         "activity": "Visit to Lalbagh Botanical Garden",
#         "location": "Lalbagh Road, Bangalore",
#         "transportation": "Taxi",
# ...
